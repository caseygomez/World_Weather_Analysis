# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 728

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call in Farenheight
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+") 
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the lat, long, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description= city_weather["weather"][0]["description"]
     
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | qaanaaq
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | hilo
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | flinders
# Processing Record 10 of Set 1 | kupang
# Processing Record 11 of Set 1 | duldurga
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | aitape
# Processing Record 15 of Set 1 | saint-philippe
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | severo-kurilsk
# Processing Record 18 of Set 1 | arraial do cabo
# Processing Record 19 of Set 1 | kruisfontein
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | sinnamary
# Processing Record 23 of Set 1 | port macquarie
# Processing Record 24 of Set 1 | hobyo
# Processing Record 25 of Set 1 | inirida
# Processing Record 26 of Set 1 | mombaca
# Processing Record 27 of Set 1 | bengkulu
# Processing Record 28 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | chulman
# Processing Record 32 of Set 1 | itacarambi
# Processing Record 33 of Set 1 | elat
# Processing Record 34 of Set 1 | tuktoyaktuk
# Processing Record 35 of Set 1 | kununurra
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | dawei
# Processing Record 38 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 1 | vao
# Processing Record 40 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 1 | talnakh
# Processing Record 43 of Set 1 | nantucket
# Processing Record 44 of Set 1 | shimoda
# Processing Record 45 of Set 1 | carnarvon
# Processing Record 46 of Set 1 | busayra
# Processing Record 47 of Set 1 | iqaluit
# Processing Record 48 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 1 | esperance
# Processing Record 1 of Set 2 | nova vicosa
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | petropavlovka
# Processing Record 4 of Set 2 | berlevag
# Processing Record 5 of Set 2 | longyearbyen
# Processing Record 6 of Set 2 | alihe
# Processing Record 7 of Set 2 | yeppoon
# Processing Record 8 of Set 2 | whitehorse
# Processing Record 9 of Set 2 | camana
# Processing Record 10 of Set 2 | yulara
# Processing Record 11 of Set 2 | khatanga
# Processing Record 12 of Set 2 | aklavik
# Processing Record 13 of Set 2 | belmonte
# Processing Record 14 of Set 2 | syracuse
# Processing Record 15 of Set 2 | sembakung
# Processing Record 16 of Set 2 | souillac
# Processing Record 17 of Set 2 | beringovskiy
# Processing Record 18 of Set 2 | acarau
# Processing Record 19 of Set 2 | verkhoyansk
# Processing Record 20 of Set 2 | hasaki
# Processing Record 21 of Set 2 | banamba
# Processing Record 22 of Set 2 | kizukuri
# Processing Record 23 of Set 2 | bambous virieux
# Processing Record 24 of Set 2 | luanda
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | hamilton
# Processing Record 27 of Set 2 | chivay
# Processing Record 28 of Set 2 | nikolskoye
# Processing Record 29 of Set 2 | malakal
# Processing Record 30 of Set 2 | walvis bay
# Processing Record 31 of Set 2 | castro
# Processing Record 32 of Set 2 | sovkhoznyy
# Processing Record 33 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 2 | lupiro
# Processing Record 35 of Set 2 | kapaa
# Processing Record 36 of Set 2 | tasiilaq
# Processing Record 37 of Set 2 | pacific grove
# Processing Record 38 of Set 2 | kursk
# Processing Record 39 of Set 2 | umm lajj
# Processing Record 40 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 2 | caravelas
# Processing Record 42 of Set 2 | torbay
# Processing Record 43 of Set 2 | klaksvik
# Processing Record 44 of Set 2 | saint-pierre
# Processing Record 45 of Set 2 | port hardy
# Processing Record 46 of Set 2 | gat
# Processing Record 47 of Set 2 | hithadhoo
# Processing Record 48 of Set 2 | brigantine
# Processing Record 49 of Set 2 | cedar city
# Processing Record 50 of Set 2 | pisco
# Processing Record 1 of Set 3 | dikson
# Processing Record 2 of Set 3 | pokhara
# Processing Record 3 of Set 3 | saskylakh
# Processing Record 4 of Set 3 | ayan
# Processing Record 5 of Set 3 | coari
# Processing Record 6 of Set 3 | bilibino
# Processing Record 7 of Set 3 | kutum
# Processing Record 8 of Set 3 | sabha
# Processing Record 9 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 3 | coihaique
# Processing Record 11 of Set 3 | taoudenni
# Processing Record 12 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 13 of Set 3 | severnyy
# Processing Record 14 of Set 3 | ravar
# Processing Record 15 of Set 3 | tshikapa
# Processing Record 16 of Set 3 | alofi
# Processing Record 17 of Set 3 | smoky lake
# Processing Record 18 of Set 3 | tambun
# Processing Record 19 of Set 3 | gorontalo
# Processing Record 20 of Set 3 | shellbrook
# Processing Record 21 of Set 3 | makakilo city
# Processing Record 22 of Set 3 | the valley
# Processing Record 23 of Set 3 | cidreira
# Processing Record 24 of Set 3 | bethel
# Processing Record 25 of Set 3 | chuy
# Processing Record 26 of Set 3 | fortuna
# Processing Record 27 of Set 3 | tiangua
# Processing Record 28 of Set 3 | kimbe
# Processing Record 29 of Set 3 | bara
# Processing Record 30 of Set 3 | bathsheba
# Processing Record 31 of Set 3 | amapa
# Processing Record 32 of Set 3 | vaini
# Processing Record 33 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 3 | ilulissat
# Processing Record 36 of Set 3 | chokurdakh
# Processing Record 37 of Set 3 | richards bay
# Processing Record 38 of Set 3 | port elizabeth
# Processing Record 39 of Set 3 | narsaq
# Processing Record 40 of Set 3 | isangel
# Processing Record 41 of Set 3 | kudahuvadhoo
# Processing Record 42 of Set 3 | martapura
# Processing Record 43 of Set 3 | batagay-alyta
# Processing Record 44 of Set 3 | rocha
# Processing Record 45 of Set 3 | gotsu
# Processing Record 46 of Set 3 | avarua
# Processing Record 47 of Set 3 | najran
# Processing Record 48 of Set 3 | san cristobal
# Processing Record 49 of Set 3 | yellowknife
# Processing Record 50 of Set 3 | tacoaleche
# Processing Record 1 of Set 4 | kot khai
# Processing Record 2 of Set 4 | chulym
# Processing Record 3 of Set 4 | butaritari
# Processing Record 4 of Set 4 | upernavik
# Processing Record 5 of Set 4 | komsomolskiy
# Processing Record 6 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 4 | cockburn town
# Processing Record 8 of Set 4 | barrow
# Processing Record 9 of Set 4 | usinsk
# Processing Record 10 of Set 4 | faya
# Processing Record 11 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 4 | tual
# Processing Record 13 of Set 4 | bredasdorp
# Processing Record 14 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 4 | lebu
# Processing Record 16 of Set 4 | salinopolis
# Processing Record 17 of Set 4 | victoria
# Processing Record 18 of Set 4 | chicama
# Processing Record 19 of Set 4 | laguna
# Processing Record 20 of Set 4 | san jose
# Processing Record 21 of Set 4 | tlaxiaco
# City not found. Skipping...
# Processing Record 22 of Set 4 | saint-francois
# Processing Record 23 of Set 4 | mataiea
# City not found. Skipping...
# Processing Record 24 of Set 4 | te anau
# Processing Record 25 of Set 4 | buala
# Processing Record 26 of Set 4 | cherskiy
# Processing Record 27 of Set 4 | lodja
# Processing Record 28 of Set 4 | itacare
# Processing Record 29 of Set 4 | akyab
# Processing Record 30 of Set 4 | rio gallegos
# Processing Record 31 of Set 4 | dafeng
# Processing Record 32 of Set 4 | oranjestad
# Processing Record 33 of Set 4 | nome
# Processing Record 34 of Set 4 | chitral
# Processing Record 35 of Set 4 | vila velha
# Processing Record 36 of Set 4 | rafaela
# Processing Record 37 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 4 | mae ramat
# Processing Record 39 of Set 4 | paamiut
# Processing Record 40 of Set 4 | mahebourg
# Processing Record 41 of Set 4 | baglung
# Processing Record 42 of Set 4 | goderich
# Processing Record 43 of Set 4 | svetlogorsk
# Processing Record 44 of Set 4 | archidona
# Processing Record 45 of Set 4 | west bay
# Processing Record 46 of Set 4 | tiksi
# Processing Record 47 of Set 4 | puri
# Processing Record 48 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 4 | urdoma
# Processing Record 50 of Set 4 | ostrovnoy
# Processing Record 1 of Set 5 | kentau
# Processing Record 2 of Set 5 | norman wells
# Processing Record 3 of Set 5 | golden
# Processing Record 4 of Set 5 | fort nelson
# Processing Record 5 of Set 5 | kahului
# Processing Record 6 of Set 5 | binga
# Processing Record 7 of Set 5 | namibe
# Processing Record 8 of Set 5 | fuxin
# Processing Record 9 of Set 5 | cabo san lucas
# Processing Record 10 of Set 5 | avera
# Processing Record 11 of Set 5 | praia da vitoria
# Processing Record 12 of Set 5 | vizinga
# Processing Record 13 of Set 5 | provideniya
# Processing Record 14 of Set 5 | sembe
# Processing Record 15 of Set 5 | kaeo
# Processing Record 16 of Set 5 | hillsborough
# Processing Record 17 of Set 5 | atasu
# Processing Record 18 of Set 5 | ilhabela
# Processing Record 19 of Set 5 | dingle
# Processing Record 20 of Set 5 | kuusamo
# Processing Record 21 of Set 5 | guymon
# Processing Record 22 of Set 5 | ati
# Processing Record 23 of Set 5 | airai
# Processing Record 24 of Set 5 | kodiak
# Processing Record 25 of Set 5 | halifax
# Processing Record 26 of Set 5 | sao felix do xingu
# Processing Record 27 of Set 5 | trelew
# Processing Record 28 of Set 5 | sovetskiy
# Processing Record 29 of Set 5 | tak
# Processing Record 30 of Set 5 | dharchula
# Processing Record 31 of Set 5 | nanortalik
# Processing Record 32 of Set 5 | plettenberg bay
# Processing Record 33 of Set 5 | saint-louis
# Processing Record 34 of Set 5 | union
# Processing Record 35 of Set 5 | ambulu
# Processing Record 36 of Set 5 | vagur
# Processing Record 37 of Set 5 | honningsvag
# Processing Record 38 of Set 5 | puerto penasco
# Processing Record 39 of Set 5 | arroyo
# Processing Record 40 of Set 5 | san juan de colon
# Processing Record 41 of Set 5 | andrelandia
# Processing Record 42 of Set 5 | anar darreh
# City not found. Skipping...
# Processing Record 43 of Set 5 | kortkeros
# Processing Record 44 of Set 5 | santa barbara
# Processing Record 45 of Set 5 | bandarbeyla
# Processing Record 46 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 5 | ribeira grande
# Processing Record 48 of Set 5 | yangshe
# Processing Record 49 of Set 5 | marzuq
# Processing Record 50 of Set 5 | sisimiut
# Processing Record 1 of Set 6 | unye
# City not found. Skipping...
# Processing Record 2 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 6 | rajauri
# Processing Record 4 of Set 6 | kaitangata
# Processing Record 5 of Set 6 | thompson
# Processing Record 6 of Set 6 | samarai
# Processing Record 7 of Set 6 | san patricio
# Processing Record 8 of Set 6 | taman
# Processing Record 9 of Set 6 | hendijan
# City not found. Skipping...
# Processing Record 10 of Set 6 | broken hill
# Processing Record 11 of Set 6 | clyde river
# Processing Record 12 of Set 6 | qaqortoq
# Processing Record 13 of Set 6 | tabou
# Processing Record 14 of Set 6 | miraflores
# Processing Record 15 of Set 6 | cape town
# Processing Record 16 of Set 6 | nouadhibou
# Processing Record 17 of Set 6 | la ronge
# Processing Record 18 of Set 6 | ponta do sol
# Processing Record 19 of Set 6 | honiara
# Processing Record 20 of Set 6 | normandin
# Processing Record 21 of Set 6 | tessalit
# Processing Record 22 of Set 6 | meulaboh
# Processing Record 23 of Set 6 | mackenzie
# Processing Record 24 of Set 6 | naryan-mar
# Processing Record 25 of Set 6 | asfi
# Processing Record 26 of Set 6 | chingirlau
# Processing Record 27 of Set 6 | arlit
# Processing Record 28 of Set 6 | huarmey
# Processing Record 29 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 6 | karratha
# Processing Record 31 of Set 6 | vestmannaeyjar
# Processing Record 32 of Set 6 | scottsbluff
# Processing Record 33 of Set 6 | cururupu
# Processing Record 34 of Set 6 | anaconda
# Processing Record 35 of Set 6 | georgetown
# Processing Record 36 of Set 6 | lubango
# Processing Record 37 of Set 6 | kushima
# Processing Record 38 of Set 6 | staryy oskol
# Processing Record 39 of Set 6 | abu jubayhah
# City not found. Skipping...
# Processing Record 40 of Set 6 | lalibela
# Processing Record 41 of Set 6 | sibolga
# Processing Record 42 of Set 6 | cayenne
# Processing Record 43 of Set 6 | husavik
# Processing Record 44 of Set 6 | pevek
# Processing Record 45 of Set 6 | cap-aux-meules
# Processing Record 46 of Set 6 | alyangula
# Processing Record 47 of Set 6 | zhangjiakou
# Processing Record 48 of Set 6 | maceio
# Processing Record 49 of Set 6 | college
# Processing Record 50 of Set 6 | shingu
# Processing Record 1 of Set 7 | saint george
# Processing Record 2 of Set 7 | nadvoitsy
# Processing Record 3 of Set 7 | gimli
# Processing Record 4 of Set 7 | vanimo
# Processing Record 5 of Set 7 | naze
# Processing Record 6 of Set 7 | zyryanovsk
# Processing Record 7 of Set 7 | abdulino
# Processing Record 8 of Set 7 | vilhena
# Processing Record 9 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 10 of Set 7 | acapulco
# Processing Record 11 of Set 7 | loreto
# Processing Record 12 of Set 7 | pingliang
# Processing Record 13 of Set 7 | yilan
# Processing Record 14 of Set 7 | warri
# Processing Record 15 of Set 7 | mogadishu
# Processing Record 16 of Set 7 | vrangel
# Processing Record 17 of Set 7 | salalah
# Processing Record 18 of Set 7 | fukue
# Processing Record 19 of Set 7 | skala
# Processing Record 20 of Set 7 | cartagena del chaira
# Processing Record 21 of Set 7 | tambopata
# Processing Record 22 of Set 7 | zlitan
# Processing Record 23 of Set 7 | zhigansk
# Processing Record 24 of Set 7 | port hawkesbury
# Processing Record 25 of Set 7 | brive-la-gaillarde
# Processing Record 26 of Set 7 | boende
# Processing Record 27 of Set 7 | zwedru
# Processing Record 28 of Set 7 | geraldton
# Processing Record 29 of Set 7 | vardo
# Processing Record 30 of Set 7 | lavrentiya
# Processing Record 31 of Set 7 | kailua
# Processing Record 32 of Set 7 | porto novo
# Processing Record 33 of Set 7 | benguela
# Processing Record 34 of Set 7 | sinyavskoye
# Processing Record 35 of Set 7 | camacha
# Processing Record 36 of Set 7 | ampanihy
# Processing Record 37 of Set 7 | bomet
# Processing Record 38 of Set 7 | tecpan
# Processing Record 39 of Set 7 | taltal
# Processing Record 40 of Set 7 | sao filipe
# Processing Record 41 of Set 7 | domoni
# Processing Record 42 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 43 of Set 7 | tumbes
# Processing Record 44 of Set 7 | yefira
# City not found. Skipping...
# Processing Record 45 of Set 7 | copiapo
# Processing Record 46 of Set 7 | kokopo
# Processing Record 47 of Set 7 | onda
# Processing Record 48 of Set 7 | sergeyevka
# Processing Record 49 of Set 7 | oktyabrskoye
# Processing Record 50 of Set 7 | marapanim
# Processing Record 1 of Set 8 | lompoc
# Processing Record 2 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 3 of Set 8 | gweta
# Processing Record 4 of Set 8 | cam pha
# City not found. Skipping...
# Processing Record 5 of Set 8 | east london
# Processing Record 6 of Set 8 | port-cartier
# Processing Record 7 of Set 8 | teahupoo
# Processing Record 8 of Set 8 | lagoa
# Processing Record 9 of Set 8 | klyuchi
# Processing Record 10 of Set 8 | bijar
# Processing Record 11 of Set 8 | dunedin
# Processing Record 12 of Set 8 | hofn
# Processing Record 13 of Set 8 | yumen
# Processing Record 14 of Set 8 | doha
# Processing Record 15 of Set 8 | ilinge
# Processing Record 16 of Set 8 | santa cruz
# Processing Record 17 of Set 8 | hualmay
# Processing Record 18 of Set 8 | lermontovka
# Processing Record 19 of Set 8 | northam
# Processing Record 20 of Set 8 | mbandaka
# Processing Record 21 of Set 8 | torres
# Processing Record 22 of Set 8 | ulaangom
# Processing Record 23 of Set 8 | dwarka
# Processing Record 24 of Set 8 | aklera
# Processing Record 25 of Set 8 | tubinskiy
# Processing Record 26 of Set 8 | tura
# Processing Record 27 of Set 8 | toamasina
# Processing Record 28 of Set 8 | sal rei
# Processing Record 29 of Set 8 | kavaratti
# Processing Record 30 of Set 8 | point pleasant
# Processing Record 31 of Set 8 | kungurtug
# Processing Record 32 of Set 8 | port blair
# Processing Record 33 of Set 8 | ola
# Processing Record 34 of Set 8 | sabang
# Processing Record 35 of Set 8 | xuddur
# Processing Record 36 of Set 8 | sadiqabad
# Processing Record 37 of Set 8 | jaffna
# Processing Record 38 of Set 8 | storforshei
# Processing Record 39 of Set 8 | goma
# Processing Record 40 of Set 8 | henties bay
# Processing Record 41 of Set 8 | enumclaw
# Processing Record 42 of Set 8 | puerto colombia
# Processing Record 43 of Set 8 | takaka
# Processing Record 44 of Set 8 | willmar
# Processing Record 45 of Set 8 | bongandanga
# Processing Record 46 of Set 8 | bell ville
# Processing Record 47 of Set 8 | coahuayana
# Processing Record 48 of Set 8 | gif-sur-yvette
# Processing Record 49 of Set 8 | alappuzha
# Processing Record 50 of Set 8 | rawson
# Processing Record 1 of Set 9 | nakhon thai
# Processing Record 2 of Set 9 | petaluma
# Processing Record 3 of Set 9 | ahome
# Processing Record 4 of Set 9 | korhogo
# Processing Record 5 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 9 | watsa
# Processing Record 7 of Set 9 | lata
# Processing Record 8 of Set 9 | vila franca do campo
# Processing Record 9 of Set 9 | santarem
# Processing Record 10 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 11 of Set 9 | gewane
# Processing Record 12 of Set 9 | penhold
# Processing Record 13 of Set 9 | villazon
# Processing Record 14 of Set 9 | toledo
# Processing Record 15 of Set 9 | tilichiki
# Processing Record 16 of Set 9 | sioux lookout
# Processing Record 17 of Set 9 | nanakuli
# Processing Record 18 of Set 9 | luderitz
# Processing Record 19 of Set 9 | nola
# Processing Record 20 of Set 9 | algiers
# Processing Record 21 of Set 9 | sai buri
# Processing Record 22 of Set 9 | bouna
# Processing Record 23 of Set 9 | zamania
# Processing Record 24 of Set 9 | marsh harbour
# Processing Record 25 of Set 9 | singaparna
# Processing Record 26 of Set 9 | borama
# City not found. Skipping...
# Processing Record 27 of Set 9 | rock springs
# Processing Record 28 of Set 9 | sahbuz
# Processing Record 29 of Set 9 | ullapool
# Processing Record 30 of Set 9 | mount gambier
# Processing Record 31 of Set 9 | sociedad
# Processing Record 32 of Set 9 | nerchinsk
# Processing Record 33 of Set 9 | gisborne
# Processing Record 34 of Set 9 | asau
# Processing Record 35 of Set 9 | pemangkat
# Processing Record 36 of Set 9 | saint-leu
# Processing Record 37 of Set 9 | tuatapere
# Processing Record 38 of Set 9 | constitucion
# Processing Record 39 of Set 9 | haines junction
# Processing Record 40 of Set 9 | nishihara
# Processing Record 41 of Set 9 | tabas
# Processing Record 42 of Set 9 | maku
# Processing Record 43 of Set 9 | lorengau
# Processing Record 44 of Set 9 | ta khmau
# Processing Record 45 of Set 9 | tranas
# Processing Record 46 of Set 9 | tezu
# Processing Record 47 of Set 9 | alvaraes
# Processing Record 48 of Set 9 | harunabad
# Processing Record 49 of Set 9 | mareeba
# Processing Record 50 of Set 9 | illapel
# Processing Record 1 of Set 10 | mwinilunga
# Processing Record 2 of Set 10 | loandjili
# Processing Record 3 of Set 10 | comodoro rivadavia
# Processing Record 4 of Set 10 | fomboni
# Processing Record 5 of Set 10 | chernyanka
# Processing Record 6 of Set 10 | turan
# Processing Record 7 of Set 10 | filingue
# Processing Record 8 of Set 10 | paramonga
# Processing Record 9 of Set 10 | adre
# Processing Record 10 of Set 10 | kalmunai
# Processing Record 11 of Set 10 | pavlivka
# Processing Record 12 of Set 10 | yerbogachen
# Processing Record 13 of Set 10 | socorro
# Processing Record 14 of Set 10 | achisay
# City not found. Skipping...
# Processing Record 15 of Set 10 | eirunepe
# Processing Record 16 of Set 10 | koupela
# Processing Record 17 of Set 10 | mayo
# Processing Record 18 of Set 10 | monte alegre
# Processing Record 19 of Set 10 | polyarnyy
# Processing Record 20 of Set 10 | kutoarjo
# Processing Record 21 of Set 10 | cochrane
# Processing Record 22 of Set 10 | buraydah
# Processing Record 23 of Set 10 | urucara
# Processing Record 24 of Set 10 | bowen
# Processing Record 25 of Set 10 | kouango
# Processing Record 26 of Set 10 | salekhard
# Processing Record 27 of Set 10 | half moon bay
# Processing Record 28 of Set 10 | ogulin
# Processing Record 29 of Set 10 | rivera
# Processing Record 30 of Set 10 | roswell
# Processing Record 31 of Set 10 | innisfail
# Processing Record 32 of Set 10 | riyadh
# Processing Record 33 of Set 10 | los llanos de aridane
# Processing Record 34 of Set 10 | tromso
# Processing Record 35 of Set 10 | yarumal
# Processing Record 36 of Set 10 | manaure
# Processing Record 37 of Set 10 | grande-synthe
# Processing Record 38 of Set 10 | byron bay
# Processing Record 39 of Set 10 | port hedland
# Processing Record 40 of Set 10 | amahai
# Processing Record 41 of Set 10 | kimparana
# Processing Record 42 of Set 10 | chernyshevskiy
# Processing Record 43 of Set 10 | saldanha
# Processing Record 44 of Set 10 | markala
# Processing Record 45 of Set 10 | mezen
# Processing Record 46 of Set 10 | bonnyville
# Processing Record 47 of Set 10 | charlestown
# Processing Record 48 of Set 10 | naron
# Processing Record 49 of Set 10 | dhidhdhoo
# Processing Record 50 of Set 10 | espanola
# Processing Record 1 of Set 11 | arkhara
# Processing Record 2 of Set 11 | ukiah
# Processing Record 3 of Set 11 | faanui
# Processing Record 4 of Set 11 | mehamn
# Processing Record 5 of Set 11 | sitka
# Processing Record 6 of Set 11 | ponta delgada
# Processing Record 7 of Set 11 | samoded
# Processing Record 8 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 9 of Set 11 | sandwick
# Processing Record 10 of Set 11 | pahrump
# Processing Record 11 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 11 | pangnirtung
# Processing Record 13 of Set 11 | beaufort
# Processing Record 14 of Set 11 | shubarkuduk
# Processing Record 15 of Set 11 | whithorn
# Processing Record 16 of Set 11 | siwani
# City not found. Skipping...
# Processing Record 17 of Set 11 | saint-ambroise
# Processing Record 18 of Set 11 | cutervo
# Processing Record 19 of Set 11 | porangatu
# Processing Record 20 of Set 11 | traverse city
# Processing Record 21 of Set 11 | banapur
# Processing Record 22 of Set 11 | ginir
# Processing Record 23 of Set 11 | cascais
# Processing Record 24 of Set 11 | yeletskiy
# City not found. Skipping...
# Processing Record 25 of Set 11 | nivala
# Processing Record 26 of Set 11 | namatanai
# Processing Record 27 of Set 11 | winnemucca
# Processing Record 28 of Set 11 | waipawa
# Processing Record 29 of Set 11 | jalu
# Processing Record 30 of Set 11 | anadyr
# Processing Record 31 of Set 11 | liminangcong
# City not found. Skipping...
# Processing Record 32 of Set 11 | weligama
# Processing Record 33 of Set 11 | garden city
# Processing Record 34 of Set 11 | valparaiso
# Processing Record 35 of Set 11 | westport
# Processing Record 36 of Set 11 | erenhot
# Processing Record 37 of Set 11 | pokanayevka
# City not found. Skipping...
# Processing Record 38 of Set 11 | leningradskiy
# Processing Record 39 of Set 11 | balezino
# Processing Record 40 of Set 11 | ancud
# Processing Record 41 of Set 11 | abnub
# Processing Record 42 of Set 11 | bay roberts
# Processing Record 43 of Set 11 | bajos de haina
# Processing Record 44 of Set 11 | ishigaki
# Processing Record 45 of Set 11 | mont-de-marsan
# Processing Record 46 of Set 11 | katsuura
# Processing Record 47 of Set 11 | ulladulla
# Processing Record 48 of Set 11 | ariquemes
# Processing Record 49 of Set 11 | skibbereen
# Processing Record 50 of Set 11 | mitsamiouli
# Processing Record 1 of Set 12 | barahona
# Processing Record 2 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 3 of Set 12 | maniitsoq
# Processing Record 4 of Set 12 | matagami
# Processing Record 5 of Set 12 | bhunya
# Processing Record 6 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 7 of Set 12 | dicabisagan
# Processing Record 8 of Set 12 | ipora
# Processing Record 9 of Set 12 | keti bandar
# Processing Record 10 of Set 12 | winsum
# Processing Record 11 of Set 12 | zhanaozen
# Processing Record 12 of Set 12 | pitimbu
# Processing Record 13 of Set 12 | manado
# Processing Record 14 of Set 12 | portland
# Processing Record 15 of Set 12 | guerrero negro
# Processing Record 16 of Set 12 | saint anthony
# Processing Record 17 of Set 12 | morehead
# Processing Record 18 of Set 12 | agarak
# Processing Record 19 of Set 12 | hun
# Processing Record 20 of Set 12 | codrington
# Processing Record 21 of Set 12 | balykshi
# Processing Record 22 of Set 12 | wattegama
# Processing Record 23 of Set 12 | glenwood springs
# Processing Record 24 of Set 12 | kavieng
# Processing Record 25 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 26 of Set 12 | kaluga
# Processing Record 27 of Set 12 | santa marta de tormes
# Processing Record 28 of Set 12 | graham
# Processing Record 29 of Set 12 | mahadday weyne
# City not found. Skipping...
# Processing Record 30 of Set 12 | misratah
# Processing Record 31 of Set 12 | ikornnes
# Processing Record 32 of Set 12 | dongfeng
# Processing Record 33 of Set 12 | ivanteyevka
# Processing Record 34 of Set 12 | okha
# Processing Record 35 of Set 12 | golynki
# Processing Record 36 of Set 12 | tianpeng
# Processing Record 37 of Set 12 | san matias
# Processing Record 38 of Set 12 | soyo
# Processing Record 39 of Set 12 | fethiye
# Processing Record 40 of Set 12 | afonso bezerra
# Processing Record 41 of Set 12 | touros
# Processing Record 42 of Set 12 | puerto escondido
# Processing Record 43 of Set 12 | beloha
# Processing Record 44 of Set 12 | jalpan
# Processing Record 45 of Set 12 | cortez
# Processing Record 46 of Set 12 | mariental
# Processing Record 47 of Set 12 | sao raimundo nonato
# Processing Record 48 of Set 12 | dubbo
# Processing Record 49 of Set 12 | luganville
# Processing Record 50 of Set 12 | eucaliptus
# Processing Record 1 of Set 13 | catabola
# Processing Record 2 of Set 13 | abu dhabi
# Processing Record 3 of Set 13 | carutapera
# Processing Record 4 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 5 of Set 13 | guilin
# Processing Record 6 of Set 13 | mirnyy
# Processing Record 7 of Set 13 | eufaula
# Processing Record 8 of Set 13 | rio grande
# Processing Record 9 of Set 13 | bukachacha
# Processing Record 10 of Set 13 | yima
# Processing Record 11 of Set 13 | atar
# Processing Record 12 of Set 13 | tondano
# Processing Record 13 of Set 13 | huangpi
# Processing Record 14 of Set 13 | kissidougou
# Processing Record 15 of Set 13 | zhitikara
# City not found. Skipping...
# Processing Record 16 of Set 13 | saint-augustin
# Processing Record 17 of Set 13 | egvekinot
# Processing Record 18 of Set 13 | aswan
# Processing Record 19 of Set 13 | mangrol
# Processing Record 20 of Set 13 | ambovombe
# Processing Record 21 of Set 13 | neryungri
# Processing Record 22 of Set 13 | kumluca
# Processing Record 23 of Set 13 | islamkot
# Processing Record 24 of Set 13 | pala
# Processing Record 25 of Set 13 | leicester
# Processing Record 26 of Set 13 | requena
# Processing Record 27 of Set 13 | kolpashevo
# Processing Record 28 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 29 of Set 13 | koslan
# Processing Record 30 of Set 13 | mineiros
# Processing Record 31 of Set 13 | necochea
# Processing Record 32 of Set 13 | guane
# Processing Record 33 of Set 13 | san antonio
# Processing Record 34 of Set 13 | artigas
# Processing Record 35 of Set 13 | hambantota
# Processing Record 36 of Set 13 | totness
# Processing Record 37 of Set 13 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 38 of Set 13 | axim
# Processing Record 39 of Set 13 | jalingo
# Processing Record 40 of Set 13 | shache
# Processing Record 41 of Set 13 | ust-kuyga
# Processing Record 42 of Set 13 | xam nua
# Processing Record 43 of Set 13 | new glasgow
# Processing Record 44 of Set 13 | anloga
# Processing Record 45 of Set 13 | pionki
# Processing Record 46 of Set 13 | falun
# Processing Record 47 of Set 13 | ahipara
# Processing Record 48 of Set 13 | itoman
# Processing Record 49 of Set 13 | khandagayty
# Processing Record 50 of Set 13 | gupitan
# Processing Record 1 of Set 14 | matara
# Processing Record 2 of Set 14 | dianopolis
# City not found. Skipping...
# Processing Record 3 of Set 14 | sambava
# Processing Record 4 of Set 14 | yangambi
# Processing Record 5 of Set 14 | cowra
# Processing Record 6 of Set 14 | katherine
# Processing Record 7 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 8 of Set 14 | tiznit
# Processing Record 9 of Set 14 | balkanabat
# Processing Record 10 of Set 14 | korla
# Processing Record 11 of Set 14 | novoselitskoye
# Processing Record 12 of Set 14 | truth or consequences
# Processing Record 13 of Set 14 | vacha
# Processing Record 14 of Set 14 | progreso
# Processing Record 15 of Set 14 | san pedro
# Processing Record 16 of Set 14 | shar
# Processing Record 17 of Set 14 | kenai
# Processing Record 18 of Set 14 | pochutla
# Processing Record 19 of Set 14 | manoel urbano
# Processing Record 20 of Set 14 | galle
# Processing Record 21 of Set 14 | gambela
# Processing Record 22 of Set 14 | gladstone
# Processing Record 23 of Set 14 | kangaatsiaq
# Processing Record 24 of Set 14 | rio verde de mato grosso
# Processing Record 25 of Set 14 | timra
# Processing Record 26 of Set 14 | quatre cocos
# Processing Record 27 of Set 14 | fountain
# Processing Record 28 of Set 14 | jensen beach
# Processing Record 29 of Set 14 | ust-nera
# Processing Record 30 of Set 14 | kindu
# Processing Record 31 of Set 14 | saint-michel-des-saints
# Processing Record 32 of Set 14 | imbituba
# Processing Record 33 of Set 14 | torrington
# Processing Record 34 of Set 14 | burkhala
# City not found. Skipping...
# Processing Record 35 of Set 14 | alta floresta
# Processing Record 36 of Set 14 | san andres
# Processing Record 37 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 14 | dali
# Processing Record 39 of Set 14 | upata
# Processing Record 40 of Set 14 | chachapoyas
# Processing Record 41 of Set 14 | floro
# Processing Record 42 of Set 14 | komsomolets
# Processing Record 43 of Set 14 | grindavik
# Processing Record 44 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 14 | chambas
# Processing Record 46 of Set 14 | sayabec
# City not found. Skipping...
# Processing Record 47 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 48 of Set 14 | altonia
# City not found. Skipping...
# Processing Record 49 of Set 14 | giyani
# Processing Record 50 of Set 14 | stutterheim
# Processing Record 1 of Set 15 | diamantino
# Processing Record 2 of Set 15 | nam tha
# City not found. Skipping...
# Processing Record 3 of Set 15 | kulunda
# Processing Record 4 of Set 15 | yonago
# Processing Record 5 of Set 15 | oranjemund
# Processing Record 6 of Set 15 | chato
# Processing Record 7 of Set 15 | kaniama
# Processing Record 8 of Set 15 | langres
# Processing Record 9 of Set 15 | podporozhye
# Processing Record 10 of Set 15 | bardiyah
# Processing Record 11 of Set 15 | banda aceh
# Processing Record 12 of Set 15 | iseyin
# Processing Record 13 of Set 15 | casablanca
# Processing Record 14 of Set 15 | kelvington
# Processing Record 15 of Set 15 | vanavara
# Processing Record 16 of Set 15 | ordu
# Processing Record 17 of Set 15 | antofagasta
# Processing Record 18 of Set 15 | mersing
# Processing Record 19 of Set 15 | jahrom
# City not found. Skipping...
# Processing Record 20 of Set 15 | qafsah
# City not found. Skipping...
# Processing Record 21 of Set 15 | swan river
# Processing Record 22 of Set 15 | cavalcante
# Processing Record 23 of Set 15 | nushki
# Processing Record 24 of Set 15 | nizhniy kuranakh
# Processing Record 25 of Set 15 | bubaque
# Processing Record 26 of Set 15 | vila do maio
# Processing Record 27 of Set 15 | nyurba
# Processing Record 28 of Set 15 | volchanets
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 668

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.tail(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 658       Antofagasta      CL -23.6500  -70.4000     63.68        67
# 659           Mersing      MY   2.4312  103.8405     77.09        89
# 660        Swan River      CA  52.1058 -101.2676     40.06        51
# 661        Cavalcante      BR -13.7975  -47.4583     90.64        18
# 662            Nushki      PK  29.5542   66.0215     66.58        10
# 663  Nizhniy Kuranakh      RU  58.8353  125.4869     24.64        97
# 664           Bubaque      GW  11.2833  -15.8333     81.73        73
# 665      Vila Do Maio      CV  15.1333  -23.2167     77.79        75
# 666            Nyurba      RU  63.2842  118.3319     26.98        92
# 667        Volchanets      RU  42.9131  132.7469     53.35        81
#
#      Cloudiness  Wind Speed Current Description
# 658           0        6.42           clear sky
# 659          55        4.18       broken clouds
# 660         100       17.43     overcast clouds
# 661          15       11.30          few clouds
# 662           0        1.81           clear sky
# 663         100        3.76          light snow
# 664          72        4.45       moderate rain
# 665          64       12.71       broken clouds
# 666         100        7.78     overcast clouds
# 667         100        2.64     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hobart      AU -42.8794  147.3294     44.46        81          75
# 1       Rikitea      PF -23.1203 -134.9692     73.49        81          59
# 2  Puerto Ayora      EC  -0.7393  -90.3518     80.56        86          81
# 3       Qaanaaq      GL  77.4840  -69.3632     29.41        78         100
# 4  Punta Arenas      CL -53.1500  -70.9167     55.51        30           0
# 5          Hilo      US  19.7297 -155.0900     85.28        95         100
# 6      Hermanus      ZA -34.4187   19.2345     61.81        85         100
# 7   New Norfolk      AU -42.7826  147.0587     44.10        63          99
# 8      Flinders      AU -34.5833  150.8552     53.38        79          76
# 9        Kupang      ID -10.1667  123.5833     79.34        82          61
#
#    Wind Speed Current Description
# 0        5.75          light rain
# 1       17.40          light rain
# 2        8.99       broken clouds
# 3       34.49                snow
# 4       19.57           clear sky
# 5        4.61     overcast clouds
# 6       15.70     overcast clouds
# 7        2.35          light rain
# 8        1.99       broken clouds
# 9        6.49       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the city_data into a WeatherPy_Database.CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
